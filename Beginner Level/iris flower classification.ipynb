# %% [markdown]
# **Lets Grow More**
#
# **Data Science Intership(VIP)**
#
# **Author:-GOLLA MACHILIKANTH YADAV**

# %% [markdown]
# ## **Title:-Iris Flower Classification Using ML**

# %% [markdown]
# The goal is to create a machine learning model that can learn from measurements of these iris whose species are already known so,that we can predict that species for new iris.

# %% [markdown]
# ### 1.Importhing library's

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns # used for data visualization and exploratory data analysis.
import sklearn
#%matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Importing dataset from csv file

# %%
iris_data=pd.read_csv("/content/iris.data")

# %%
iris_data.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris_data.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
columns=['sepal_length','sepal_width','petal_length','petal_width','class']

# %%
iris_data.columns=columns
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %% [markdown]
# ## 2.**Understanding the dataset** **bold text**

# %%
iris_data.shape
# Out:
# (149, 5)

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  149 non-null    float64
#  1   sepal_width   149 non-null    float64
#  2   petal_length  149 non-null    float64
#  3   petal_width   149 non-null    float64
#  4   class         149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # 3.Missing Value's Imputation

# %%
iris_data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %% [markdown]
# ## **4.Data Visualization**

# %% [markdown]
# box plot

# %%
sns.boxplot(data=iris_data,width=0.5,fliersize=5)
sns.set(rc={"figure.figsize":(6,6)})

# %% [markdown]
# Exploring the correlation between different columns

# %% [markdown]
# Heatmap

# %%
#plotting a heatmap to determine  the correlation between columns quantities
corr=iris_data.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr,annot=True)
iris_data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %% [markdown]
# from the heatmap we can see the correlation between different features that can affect a iris_data listing .There's correlation among sepal_length to review to petal_width.petal_length gives the same information.

# %%
violin plot

# %%
sns.violinplot(y='class',x='sepal_length',data=iris_data,inner="quartile")
plt.show()
sns.violinplot(y='class',x='sepal_length',data=iris_data,inner='quartile')
plt.show()
sns.violinplot(y='class',x='petal_length',data=iris_data,inner='quartile')
plt.show()

# %% [markdown]
# The above-plotted violin plot says that iris_setosa class is having  a smaller petal length and petal width compared to other class.

# %% [markdown]
# # **5.model building-part-A**

# %% [markdown]
# As we have measurements for which we know the correct species of iris, this is a supervised learning problem. we want to predict one of the several options(the species of iris),making it an example of a classification problem.
# to test the model's performance,we show it new data for which we have label this is usually done by splitting the labbeled data we have collected into two parts.one part of the data is used to build the machine learning model,and is called the trainng data or traning set (which we call x-train and y_train).the rest of the data will be used to test how well the model works,this is called the test set,test data ,or hold-our set (which we call X_test,Y_test).

# %% [markdown]
# **5.1.x is having all the dependent variables.**

# %% [markdown]
# Y is having an independent variable (here in this case 'calss' is an independent variable).

# %%
x=iris_data.drop(['class'],axis=1)
y=iris_data['class']
print(f'x shape:{x.shape} |y shape :{y.shape}')
# Out:
# x shape:(149, 4) |y shape :(149,)

# %% [markdown]
# here,we can see from the output that the x has 150 rows and 4 columns whereas y has 150 rows and only one column.

# %% [markdown]
# 5.2 train test split
# splitting our dataset into train and test using train_test_split(),where we are doing here is talking 180% of data to train our model, and 20% that we will hold back as a validation dataset:

# %%
x_train , x_test,y_train,y_test=train_test_split(x,y,test_size=0.10,random_state=1)

# %% [markdown]
# 5.3 Model creation
# Support Vector Machines (svm) Support Vector Classifier(SVC) is performing better than other algorithms. lets's train SVC model on our training  set and predict on test set in the next step.

# %%
model=[]
model.append(('svc',SVC(gamma='auto')))

# %% [markdown]
# # 6.Model Building -part-B

# %% [markdown]
# 6.1.We are defining our svc model and passing gamma as auto.
#
# 6.2.After that fitting/training the model on X-train and Y_train using.fit() method.
#
# 6.3 then we are predicting on X-test using.predict() method.model =svc (gamma='auto')

# %%
model=SVC(gamma='auto')
model.fit(x_train,y_train)
prediction=model.predict(x_test)

# %% [markdown]
# # 6.4 Now checking the accuracy of model

# %%
print(f'Test Acurracy:{accuracy_score(y_test,prediction)}')
print(f'Classification Report:\n{classification_report (y_test,prediction)} ')
# Out:
# Test Acurracy:0.9333333333333333
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         4
# Iris-versicolor       0.90      1.00      0.95         9
#  Iris-virginica       1.00      0.50      0.67         2
#
#        accuracy                           0.93        15
#       macro avg       0.97      0.83      0.87        15
#    weighted avg       0.94      0.93      0.92        15

# %% [markdown]
# #Conclusion
# For this model, the accuracy on the test set is 0.93,which means the right prediction for 93% of the given dataset.we can expect the model to be correct 93% of the time for predicting the species of new iris.This is a high level of accuracy and it means that our model may be trustworthy enough to use
#
# -------------------------------thankyou-------------------------------
